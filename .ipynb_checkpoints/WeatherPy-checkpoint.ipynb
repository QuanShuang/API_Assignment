# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and humidity. However, when it approaches the equator, there are more cities with humidity below 20%.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0 and 90% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 30 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/forecast?"+ "&APPID=" + api_key+"&units=imperial"

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

city_number=1
set_number=1
city_name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind=[]

for city in cities:
    query_url=base_url+"&q=" + city 
    weather_json=requests.get(query_url).json()
    
    try:
        city_name.append(city)
        cloudiness.append(weather_json["list"][0]["clouds"]["all"])
        country.append(weather_json["city"]["country"])
        date.append(weather_json["list"][0]["dt"])
        humidity.append(weather_json["list"][0]["main"]["humidity"])
        lat.append(weather_json["city"]["coord"]["lat"])
        lng.append(weather_json["city"]["coord"]["lon"])
        max_temp.append(weather_json["list"][0]["main"]["temp_max"])
        wind.append(weather_json["list"][0]["wind"]["speed"])
        print(f"Processing Record {city_number} of Set {set_number} | {city}")
        print(query_url)
    
        if city_number>=49:
            set_number+=1
            city_number=1
        else:
            city_number+=1
    
    except (KeyError):
        print("City not found. Skipping...")
        city_name.remove(city)
                    
print(f"-----------------------------")
print("Data Retrieval Complete")
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=esperance
# Processing Record 2 of Set 1 | itaquyry
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=itaquyry
# Processing Record 3 of Set 1 | sirohi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sirohi
# Processing Record 4 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=avarua
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=busselton
# Processing Record 6 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=albany
# Processing Record 7 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=qaanaaq
# City not found. Skipping...
# Processing Record 8 of Set 1 | egvekinot
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=egvekinot
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vaini
# Processing Record 10 of Set 1 | terrace
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=terrace
# Processing Record 11 of Set 1 | caravelas
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=caravelas
# Processing Record 12 of Set 1 | daru
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=daru
# Processing Record 13 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tuatapere
# Processing Record 14 of Set 1 | nogliki
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nogliki
# Processing Record 15 of Set 1 | novo aripuana
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=novo aripuana
# Processing Record 16 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saskylakh
# City not found. Skipping...
# Processing Record 17 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mataura
# Processing Record 18 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=pangnirtung
# Processing Record 19 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hilo
# Processing Record 20 of Set 1 | brandon
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=brandon
# Processing Record 21 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=new norfolk
# Processing Record 22 of Set 1 | jalu
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=jalu
# City not found. Skipping...
# Processing Record 23 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saint george
# Processing Record 24 of Set 1 | zhigalovo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=zhigalovo
# Processing Record 25 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kapaa
# Processing Record 26 of Set 1 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kudahuvadhoo
# Processing Record 27 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tiksi
# Processing Record 28 of Set 1 | yar-sale
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=yar-sale
# Processing Record 29 of Set 1 | sao domingos
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sao domingos
# Processing Record 30 of Set 1 | noumea
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=noumea
# Processing Record 31 of Set 1 | breves
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=breves
# Processing Record 32 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ushuaia
# Processing Record 33 of Set 1 | walvis bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=walvis bay
# Processing Record 34 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hobart
# Processing Record 35 of Set 1 | ruwi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ruwi
# Processing Record 36 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=barrow
# Processing Record 37 of Set 1 | vangaindrano
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vangaindrano
# Processing Record 38 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saldanha
# Processing Record 39 of Set 1 | laguna
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=laguna
# Processing Record 40 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=rikitea
# Processing Record 41 of Set 1 | hearst
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hearst
# Processing Record 42 of Set 1 | ketchikan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ketchikan
# Processing Record 43 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hermanus
# Processing Record 44 of Set 1 | usinsk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=usinsk
# Processing Record 45 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saint-philippe
# Processing Record 46 of Set 1 | kazachinskoye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kazachinskoye
# Processing Record 47 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=punta arenas
# Processing Record 48 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=aklavik
# Processing Record 49 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kavieng
# Processing Record 1 of Set 2 | richards bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=richards bay
# Processing Record 2 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=butaritari
# Processing Record 3 of Set 2 | naze
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=naze
# City not found. Skipping...
# Processing Record 4 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=carnarvon
# Processing Record 5 of Set 2 | visnes
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=visnes
# Processing Record 6 of Set 2 | palmer
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=palmer
# Processing Record 7 of Set 2 | praia da vitoria
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=praia da vitoria
# Processing Record 8 of Set 2 | rawson
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=rawson
# Processing Record 9 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mahebourg
# Processing Record 10 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=longyearbyen
# Processing Record 11 of Set 2 | pelym
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=pelym
# City not found. Skipping...
# Processing Record 12 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=severo-kurilsk
# Processing Record 13 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bathsheba
# Processing Record 14 of Set 2 | tezu
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tezu
# Processing Record 15 of Set 2 | isangel
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=isangel
# Processing Record 16 of Set 2 | vuktyl
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vuktyl
# Processing Record 17 of Set 2 | durango
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=durango
# Processing Record 18 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hasaki
# Processing Record 19 of Set 2 | garmsar
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=garmsar
# Processing Record 20 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ponta do sol
# Processing Record 21 of Set 2 | devils lake
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=devils lake
# Processing Record 22 of Set 2 | lavrentiya
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lavrentiya
# Processing Record 23 of Set 2 | pindobacu
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=pindobacu
# Processing Record 24 of Set 2 | saint-francois
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saint-francois
# Processing Record 25 of Set 2 | saumur
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saumur
# Processing Record 26 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=port elizabeth
# Processing Record 27 of Set 2 | kahului
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kahului
# City not found. Skipping...
# Processing Record 28 of Set 2 | monaragala
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=monaragala
# City not found. Skipping...
# Processing Record 29 of Set 2 | alofi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=alofi
# Processing Record 30 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ilulissat
# Processing Record 31 of Set 2 | geraldton
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=geraldton
# Processing Record 32 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=torbay
# Processing Record 33 of Set 2 | zhigansk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=zhigansk
# Processing Record 34 of Set 2 | caloto
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=caloto
# Processing Record 35 of Set 2 | lasa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lasa
# Processing Record 36 of Set 2 | kirkwood
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kirkwood
# Processing Record 37 of Set 2 | half moon bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=half moon bay
# Processing Record 38 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=faanui
# Processing Record 39 of Set 2 | kirakira
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kirakira
# Processing Record 40 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=east london
# Processing Record 41 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mar del plata
# Processing Record 42 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tasiilaq
# Processing Record 43 of Set 2 | macau
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=macau
# Processing Record 44 of Set 2 | ipameri
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ipameri
# City not found. Skipping...
# Processing Record 45 of Set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=coquimbo
# Processing Record 46 of Set 2 | thornton
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=thornton
# Processing Record 47 of Set 2 | lithakia
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lithakia
# Processing Record 48 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=jamestown
# Processing Record 49 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bredasdorp
# Processing Record 1 of Set 3 | port alfred
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=port alfred
# Processing Record 2 of Set 3 | glenwood springs
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=glenwood springs
# Processing Record 3 of Set 3 | chicama
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chicama
# Processing Record 4 of Set 3 | nanzhang
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nanzhang
# Processing Record 5 of Set 3 | puerto penasco
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=puerto penasco
# Processing Record 6 of Set 3 | warragul
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=warragul
# Processing Record 7 of Set 3 | filadelfia
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=filadelfia
# Processing Record 8 of Set 3 | fort smith
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=fort smith
# Processing Record 9 of Set 3 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=krasnyy chikoy
# Processing Record 10 of Set 3 | brigantine
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=brigantine
# Processing Record 11 of Set 3 | luena
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=luena
# Processing Record 12 of Set 3 | townsville
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=townsville
# Processing Record 13 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lompoc
# Processing Record 14 of Set 3 | vao
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vao
# Processing Record 15 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bluff
# City not found. Skipping...
# Processing Record 16 of Set 3 | biak
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=biak
# Processing Record 17 of Set 3 | hofn
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hofn
# Processing Record 18 of Set 3 | kotagiri
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kotagiri
# Processing Record 19 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nikolskoye
# City not found. Skipping...
# Processing Record 20 of Set 3 | medicine hat
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=medicine hat
# Processing Record 21 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=husavik
# Processing Record 22 of Set 3 | solton
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=solton
# City not found. Skipping...
# Processing Record 23 of Set 3 | ruteng
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ruteng
# Processing Record 24 of Set 3 | huaiyin
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=huaiyin
# Processing Record 25 of Set 3 | sikasso
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sikasso
# Processing Record 26 of Set 3 | monte plata
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=monte plata
# Processing Record 27 of Set 3 | correntina
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=correntina
# Processing Record 28 of Set 3 | cape town
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cape town
# Processing Record 29 of Set 3 | luderitz
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=luderitz
# Processing Record 30 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hithadhoo
# Processing Record 31 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=arraial do cabo
# Processing Record 32 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=constitucion
# Processing Record 33 of Set 3 | tres arroyos
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tres arroyos
# City not found. Skipping...
# Processing Record 34 of Set 3 | novoseleznevo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=novoseleznevo
# Processing Record 35 of Set 3 | boa vista
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=boa vista
# Processing Record 36 of Set 3 | thinadhoo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=thinadhoo
# Processing Record 37 of Set 3 | yulara
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=yulara
# Processing Record 38 of Set 3 | xining
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=xining
# Processing Record 39 of Set 3 | starotimoshkino
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=starotimoshkino
# Processing Record 40 of Set 3 | mezen
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mezen
# Processing Record 41 of Set 3 | aranos
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=aranos
# Processing Record 42 of Set 3 | morant bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=morant bay
# Processing Record 43 of Set 3 | cape coast
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cape coast
# Processing Record 44 of Set 3 | mobaye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mobaye
# Processing Record 45 of Set 3 | merauke
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=merauke
# Processing Record 46 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=castro
# Processing Record 47 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lebu
# City not found. Skipping...
# Processing Record 48 of Set 3 | ponta delgada
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ponta delgada
# Processing Record 49 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ribeira grande
# Processing Record 1 of Set 4 | hami
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hami
# Processing Record 2 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=souillac
# Processing Record 3 of Set 4 | ngunguru
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ngunguru
# Processing Record 4 of Set 4 | kyabram
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kyabram
# Processing Record 5 of Set 4 | lagoa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lagoa
# Processing Record 6 of Set 4 | tulle
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tulle
# Processing Record 7 of Set 4 | provideniya
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=provideniya
# Processing Record 8 of Set 4 | yellowknife
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=yellowknife
# Processing Record 9 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=thompson
# Processing Record 10 of Set 4 | sechura
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sechura
# Processing Record 11 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tuktoyaktuk
# Processing Record 12 of Set 4 | basco
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=basco
# Processing Record 13 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kodiak
# Processing Record 14 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=upernavik
# Processing Record 15 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vila velha
# Processing Record 16 of Set 4 | siocon
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=siocon
# Processing Record 17 of Set 4 | kisangani
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kisangani
# Processing Record 18 of Set 4 | tari
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tari
# Processing Record 19 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bethel
# Processing Record 20 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vostok
# City not found. Skipping...
# Processing Record 21 of Set 4 | galesong
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=galesong
# Processing Record 22 of Set 4 | isabela
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=isabela
# City not found. Skipping...
# Processing Record 23 of Set 4 | rockland
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=rockland
# City not found. Skipping...
# Processing Record 24 of Set 4 | beloha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=beloha
# Processing Record 25 of Set 4 | cabo san lucas
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cabo san lucas
# City not found. Skipping...
# Processing Record 26 of Set 4 | goundam
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=goundam
# City not found. Skipping...
# Processing Record 27 of Set 4 | cartagena
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cartagena
# Processing Record 28 of Set 4 | cockburn town
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cockburn town
# Processing Record 29 of Set 4 | zhezkazgan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=zhezkazgan
# Processing Record 30 of Set 4 | armidale
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=armidale
# City not found. Skipping...
# Processing Record 31 of Set 4 | karratha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=karratha
# Processing Record 32 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kruisfontein
# Processing Record 33 of Set 4 | kuryk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kuryk
# Processing Record 34 of Set 4 | nouakchott
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nouakchott
# Processing Record 35 of Set 4 | kenitra
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kenitra
# Processing Record 36 of Set 4 | dutse
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dutse
# Processing Record 37 of Set 4 | nabire
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nabire
# Processing Record 38 of Set 4 | emba
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=emba
# Processing Record 39 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dikson
# City not found. Skipping...
# Processing Record 40 of Set 4 | dunedin
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dunedin
# City not found. Skipping...
# Processing Record 41 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bambous virieux
# Processing Record 42 of Set 4 | byron bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=byron bay
# Processing Record 43 of Set 4 | rocha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=rocha
# Processing Record 44 of Set 4 | manoel urbano
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=manoel urbano
# Processing Record 45 of Set 4 | san cristobal
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=san cristobal
# Processing Record 46 of Set 4 | porto torres
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=porto torres
# Processing Record 47 of Set 4 | songjianghe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=songjianghe
# Processing Record 48 of Set 4 | meadow lake
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=meadow lake
# Processing Record 49 of Set 4 | bull savanna
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bull savanna
# Processing Record 1 of Set 5 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mayor pablo lagerenza
# Processing Record 2 of Set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cherskiy
# Processing Record 3 of Set 5 | poya
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=poya
# City not found. Skipping...
# Processing Record 4 of Set 5 | ostrovnoy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ostrovnoy
# Processing Record 5 of Set 5 | arroio grande
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=arroio grande
# Processing Record 6 of Set 5 | kingaroy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kingaroy
# Processing Record 7 of Set 5 | ambilobe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ambilobe
# Processing Record 8 of Set 5 | avera
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=avera
# Processing Record 9 of Set 5 | wajir
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=wajir
# Processing Record 10 of Set 5 | halmstad
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=halmstad
# Processing Record 11 of Set 5 | ampanihy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ampanihy
# Processing Record 12 of Set 5 | honiara
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=honiara
# Processing Record 13 of Set 5 | sorland
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sorland
# Processing Record 14 of Set 5 | chapais
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chapais
# City not found. Skipping...
# Processing Record 15 of Set 5 | muros
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=muros
# Processing Record 16 of Set 5 | te anau
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=te anau
# Processing Record 17 of Set 5 | malinovskiy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=malinovskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | casino
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=casino
# Processing Record 19 of Set 5 | benjamin hill
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=benjamin hill
# Processing Record 20 of Set 5 | antofagasta
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=antofagasta
# Processing Record 21 of Set 5 | lumphat
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lumphat
# Processing Record 22 of Set 5 | porto novo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=porto novo
# Processing Record 23 of Set 5 | aitape
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=aitape
# Processing Record 24 of Set 5 | nanakuli
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nanakuli
# Processing Record 25 of Set 5 | chagoda
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chagoda
# Processing Record 26 of Set 5 | glendive
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=glendive
# Processing Record 27 of Set 5 | fairbanks
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=fairbanks
# Processing Record 28 of Set 5 | padang
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=padang
# Processing Record 29 of Set 5 | labuhan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=labuhan
# Processing Record 30 of Set 5 | cervo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cervo
# Processing Record 31 of Set 5 | banjar
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=banjar
# Processing Record 32 of Set 5 | san jose de rio tinto
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=san jose de rio tinto
# Processing Record 33 of Set 5 | uglovskoye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=uglovskoye
# Processing Record 34 of Set 5 | stykkisholmur
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=stykkisholmur
# Processing Record 35 of Set 5 | serenje
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=serenje
# Processing Record 36 of Set 5 | ekhabi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ekhabi
# Processing Record 37 of Set 5 | kaitangata
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kaitangata
# Processing Record 38 of Set 5 | russell
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=russell
# Processing Record 39 of Set 5 | north bend
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=north bend
# Processing Record 40 of Set 5 | jesus de otoro
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=jesus de otoro
# Processing Record 41 of Set 5 | roding
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=roding
# Processing Record 42 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nanortalik
# Processing Record 43 of Set 5 | kemise
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kemise
# Processing Record 44 of Set 5 | erzin
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=erzin
# Processing Record 45 of Set 5 | port hedland
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=port hedland
# Processing Record 46 of Set 5 | tefe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tefe
# Processing Record 47 of Set 5 | bambanglipuro
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bambanglipuro
# Processing Record 48 of Set 5 | llano de piedra
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=llano de piedra
# City not found. Skipping...
# Processing Record 49 of Set 5 | iqaluit
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=iqaluit
# Processing Record 1 of Set 6 | algeciras
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=algeciras
# Processing Record 2 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=clyde river
# Processing Record 3 of Set 6 | senanga
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=senanga
# Processing Record 4 of Set 6 | khatanga
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=khatanga
# Processing Record 5 of Set 6 | mont-de-marsan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mont-de-marsan
# Processing Record 6 of Set 6 | newport
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=newport
# City not found. Skipping...
# Processing Record 7 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=katsuura
# Processing Record 8 of Set 6 | liaqatabad
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=liaqatabad
# Processing Record 9 of Set 6 | palauig
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=palauig
# Processing Record 10 of Set 6 | bellary
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bellary
# City not found. Skipping...
# Processing Record 11 of Set 6 | alihe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=alihe
# Processing Record 12 of Set 6 | plettenberg bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=plettenberg bay
# Processing Record 13 of Set 6 | atuona
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=atuona
# Processing Record 14 of Set 6 | eregli
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=eregli
# Processing Record 15 of Set 6 | nanga eboko
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nanga eboko
# Processing Record 16 of Set 6 | coahuayana
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=coahuayana
# Processing Record 17 of Set 6 | matara
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=matara
# Processing Record 18 of Set 6 | grindavik
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=grindavik
# Processing Record 19 of Set 6 | dabola
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dabola
# Processing Record 20 of Set 6 | forio
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=forio
# Processing Record 21 of Set 6 | kaeo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kaeo
# Processing Record 22 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chuy
# City not found. Skipping...
# Processing Record 23 of Set 6 | yaring
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=yaring
# City not found. Skipping...
# Processing Record 24 of Set 6 | puerto ayora
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=puerto ayora
# City not found. Skipping...
# Processing Record 25 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=norman wells
# Processing Record 26 of Set 6 | sandy bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sandy bay
# Processing Record 27 of Set 6 | turayf
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=turayf
# Processing Record 28 of Set 6 | puro
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=puro
# Processing Record 29 of Set 6 | axim
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=axim
# Processing Record 30 of Set 6 | chalus
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chalus
# Processing Record 31 of Set 6 | guozhen
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=guozhen
# Processing Record 32 of Set 6 | general pico
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=general pico
# Processing Record 33 of Set 6 | romitan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=romitan
# Processing Record 34 of Set 6 | nieuw amsterdam
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nieuw amsterdam
# Processing Record 35 of Set 6 | ahipara
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ahipara
# Processing Record 36 of Set 6 | nantucket
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nantucket
# Processing Record 37 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=pisco
# Processing Record 38 of Set 6 | fasa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=fasa
# Processing Record 39 of Set 6 | mbini
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mbini
# Processing Record 40 of Set 6 | brus laguna
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=brus laguna
# Processing Record 41 of Set 6 | lata
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lata
# Processing Record 42 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=haines junction
# Processing Record 43 of Set 6 | fukue
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=fukue
# Processing Record 44 of Set 6 | gat
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=gat
# City not found. Skipping...
# Processing Record 45 of Set 6 | altamont
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=altamont
# Processing Record 46 of Set 6 | hamilton
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hamilton
# City not found. Skipping...
# Processing Record 47 of Set 6 | saint-leu
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saint-leu
# Processing Record 48 of Set 6 | guye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=guye
# Processing Record 49 of Set 6 | kirov
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kirov
# Processing Record 1 of Set 7 | kailua
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kailua
# Processing Record 2 of Set 7 | dali
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dali
# Processing Record 3 of Set 7 | sulangan
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sulangan
# City not found. Skipping...
# Processing Record 4 of Set 7 | bubaque
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bubaque
# Processing Record 5 of Set 7 | udachnyy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=udachnyy
# Processing Record 6 of Set 7 | tinskoy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tinskoy
# City not found. Skipping...
# Processing Record 7 of Set 7 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vestmannaeyjar
# Processing Record 8 of Set 7 | talcahuano
# ...
# Processing Record 39 of Set 10 | altay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=altay
# Processing Record 40 of Set 10 | san patricio
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=san patricio
# Processing Record 41 of Set 10 | clarence town
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=clarence town
# Processing Record 42 of Set 10 | beibei
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=beibei
# Processing Record 43 of Set 10 | swan river
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=swan river
# Processing Record 44 of Set 10 | salinopolis
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=salinopolis
# Processing Record 45 of Set 10 | mecca
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mecca
# City not found. Skipping...
# Processing Record 46 of Set 10 | henties bay
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=henties bay
# Processing Record 47 of Set 10 | sao joao da barra
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=sao joao da barra
# Processing Record 48 of Set 10 | petawawa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=petawawa
# Processing Record 49 of Set 10 | cascavel
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cascavel
# Processing Record 1 of Set 11 | antalaha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=antalaha
# Processing Record 2 of Set 11 | ostersund
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ostersund
# Processing Record 3 of Set 11 | arman
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=arman
# Processing Record 4 of Set 11 | ballina
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ballina
# Processing Record 5 of Set 11 | beira
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=beira
# Processing Record 6 of Set 11 | jumla
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=jumla
# City not found. Skipping...
# Processing Record 7 of Set 11 | nchelenge
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nchelenge
# Processing Record 8 of Set 11 | balaguer
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=balaguer
# Processing Record 9 of Set 11 | tabas
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tabas
# Processing Record 10 of Set 11 | broome
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=broome
# Processing Record 11 of Set 11 | narsaq
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=narsaq
# Processing Record 12 of Set 11 | tchibanga
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tchibanga
# Processing Record 13 of Set 11 | mago
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mago
# Processing Record 14 of Set 11 | erdenet
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=erdenet
# Processing Record 15 of Set 11 | mastic beach
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mastic beach
# Processing Record 16 of Set 11 | dakar
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dakar
# Processing Record 17 of Set 11 | paramonga
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=paramonga
# Processing Record 18 of Set 11 | santa cruz
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=santa cruz
# Processing Record 19 of Set 11 | tacoronte
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tacoronte
# Processing Record 20 of Set 11 | goderich
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=goderich
# Processing Record 21 of Set 11 | lugo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lugo
# Processing Record 22 of Set 11 | rosarito
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=rosarito
# Processing Record 23 of Set 11 | vanavara
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vanavara
# Processing Record 24 of Set 11 | cocachacra
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cocachacra
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 11 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=san carlos de bariloche
# Processing Record 26 of Set 11 | nizwa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nizwa
# Processing Record 27 of Set 11 | port-gentil
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=port-gentil
# Processing Record 28 of Set 11 | arcachon
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=arcachon
# Processing Record 29 of Set 11 | neath
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=neath
# City not found. Skipping...
# Processing Record 30 of Set 11 | bauchi
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bauchi
# Processing Record 31 of Set 11 | nehe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nehe
# Processing Record 32 of Set 11 | skjervoy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=skjervoy
# Processing Record 33 of Set 11 | abu samrah
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=abu samrah
# Processing Record 34 of Set 11 | fort nelson
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=fort nelson
# Processing Record 35 of Set 11 | harper
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=harper
# Processing Record 36 of Set 11 | hailey
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=hailey
# Processing Record 37 of Set 11 | miyako
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=miyako
# Processing Record 38 of Set 11 | vila franca do campo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vila franca do campo
# Processing Record 39 of Set 11 | cruzeiro do sul
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=cruzeiro do sul
# City not found. Skipping...
# Processing Record 40 of Set 11 | nyrob
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nyrob
# Processing Record 41 of Set 11 | matagami
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=matagami
# Processing Record 42 of Set 11 | wanganui
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=wanganui
# Processing Record 43 of Set 11 | pryazha
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=pryazha
# Processing Record 44 of Set 11 | la palma
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=la palma
# Processing Record 45 of Set 11 | puerto leguizamo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=puerto leguizamo
# Processing Record 46 of Set 11 | qaqortoq
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=qaqortoq
# Processing Record 47 of Set 11 | novyy urgal
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=novyy urgal
# Processing Record 48 of Set 11 | tamandare
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tamandare
# Processing Record 49 of Set 11 | lhokseumawe
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=lhokseumawe
# Processing Record 1 of Set 12 | staryy nadym
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=staryy nadym
# Processing Record 2 of Set 12 | surazh
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=surazh
# Processing Record 3 of Set 12 | awjilah
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=awjilah
# Processing Record 4 of Set 12 | saint-gaudens
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=saint-gaudens
# Processing Record 5 of Set 12 | tamasane
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tamasane
# Processing Record 6 of Set 12 | bandarbeyla
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=bandarbeyla
# Processing Record 7 of Set 12 | verkhoyansk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=verkhoyansk
# Processing Record 8 of Set 12 | kargalinskaya
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kargalinskaya
# Processing Record 9 of Set 12 | puerto narino
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=puerto narino
# Processing Record 10 of Set 12 | mulege
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=mulege
# Processing Record 11 of Set 12 | nouadhibou
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=nouadhibou
# City not found. Skipping...
# Processing Record 12 of Set 12 | tevaitoa
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tevaitoa
# Processing Record 13 of Set 12 | khargone
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=khargone
# Processing Record 14 of Set 12 | alexandria
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=alexandria
# Processing Record 15 of Set 12 | teseney
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=teseney
# Processing Record 16 of Set 12 | elban
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=elban
# Processing Record 17 of Set 12 | charyshskoye
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=charyshskoye
# Processing Record 18 of Set 12 | makakilo city
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=makakilo city
# Processing Record 19 of Set 12 | great yarmouth
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=great yarmouth
# Processing Record 20 of Set 12 | vaitape
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=vaitape
# Processing Record 21 of Set 12 | shelburne
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=shelburne
# Processing Record 22 of Set 12 | wailuku
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=wailuku
# Processing Record 23 of Set 12 | emerald
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=emerald
# Processing Record 24 of Set 12 | dingle
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=dingle
# Processing Record 25 of Set 12 | arroyo
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=arroyo
# Processing Record 26 of Set 12 | ust-tsilma
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ust-tsilma
# Processing Record 27 of Set 12 | ortona
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ortona
# Processing Record 28 of Set 12 | zhirnovsk
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=zhirnovsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | minab
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=minab
# Processing Record 30 of Set 12 | tarauaca
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=tarauaca
# Processing Record 31 of Set 12 | ginda
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ginda
# City not found. Skipping...
# Processing Record 32 of Set 12 | magistralnyy
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=magistralnyy
# Processing Record 33 of Set 12 | kitimat
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=kitimat
# Processing Record 34 of Set 12 | chingirlau
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=chingirlau
# Processing Record 35 of Set 12 | urbino
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=urbino
# Processing Record 36 of Set 12 | terrak
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=terrak
# Processing Record 37 of Set 12 | namatanai
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=namatanai
# Processing Record 38 of Set 12 | ayorou
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=ayorou
# Processing Record 39 of Set 12 | buritis
# http://api.openweathermap.org/data/2.5/forecast?&APPID=c673e7b2bb1e280d877b18e2468eefcd&units=imperial&q=buritis
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check uniqueness
city_unique=[]
for city in city_name:
    if city in city_unique:
        city_unique=city_unique
    else:
        city_unique.append(city)

if len(city_unique)==len(city_name):
    print("All cities are unique")
# Out:
# All cities are unique

# %%
# Convert lists of data into dataframe
city_df={"City":city_unique,"Cloudiness":cloudiness,"Country":country,
         "Date":date,"Humidity":humidity,"Lat":lat,"Lng":lng,"Max Temp":max_temp,"Wind Speed":wind}
city_df=pd.DataFrame(city_df)
city_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0  esperance          92      TT  1552316400        74  10.2447  -61.4506
# 1   itaquyry           8      PY  1552316400        78 -24.9334  -55.2167
# 2     sirohi           0      IN  1552316400        39  24.8858   72.8589
# 3     avarua          36      CK  1552316400       100 -21.2078 -159.7750
# 4  busselton           0      AU  1552316400       100 -33.6445  115.3489
#
#    Max Temp  Wind Speed
# 0     80.58        6.71
# 1     83.59        6.82
# 2     65.28        3.13
# 3     79.85       19.01
# 4     66.26       16.22

# %%
city_df.count()
# Out:
# City          578
# Cloudiness    578
# Country       578
# Date          578
# Humidity      578
# Lat           578
# Lng           578
# Max Temp      578
# Wind Speed    578
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"
city_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker="o",c="b",edgecolors="black", alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2019/03/11)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat vs Temp Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Humidity"], marker="o",c="b",edgecolors="black", alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2019/03/11)")
plt.ylabel("Humidity (%))")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Cloudiness"], marker="o",c="b",edgecolors="black", alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2019/03/11)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Wind Speed"], marker="o",c="b",edgecolors="black", alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2019/03/11)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat vs Wind Speed.png")

# Show plot
plt.show()
